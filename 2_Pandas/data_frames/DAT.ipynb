# %%
import pandas as pd

# %%
nba = pd.read_csv("nba.csv")
nba.head(20)
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     373 non-null object
# Salary      446 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
nba[["Name","Weight"]].head(5)
#will get data from these two rows
# Out:
#             Name  Weight
# 0  Avery Bradley   180.0
# 1    Jae Crowder   235.0
# 2   John Holland   205.0
# 3    R.J. Hunter   185.0
# 4  Jonas Jerebko   231.0

# %%
nba["Sport"] = "Football"
#will create an additional column called Sport and will assign the value football to all the rows

# %%
nba.insert(3, column = "Sport", value = "Football")

# %%
nba.dropna(subset = ["Salary", "College"])
#will drop the defined rows

# %%
nba.fillna(0).head(30)
#will fill the NaN or null values wit 0

# %%
nba["Salary"] = nba["Salary"].astype("int")
#will convert the values into integer

# %%
nba[nba["Team"] == "Boston Celtics"]
#will get the team name called Boston Celtics from all the rows in column team
# Out:
#                         Name            Team  Number Position   Age Height  \
# 0              Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2
# 1                Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6
# 2               John Holland  Boston Celtics    30.0       SG  27.0    6-5
# 3                R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5
# 4              Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10
# 5               Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9
# 6              Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8
# 7               Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0
# 8               Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2
# 9               Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4
# 10           Jared Sullinger  Boston Celtics     7.0        C  24.0    6-9
# ...

# %%
#INDEXING and DROPING COLUMNS AND ROWS

# %%
pd.read_csv("jamesbond.csv", index_col = "Film")

# %%
pd.read_csv("jamesbond.csv", index_col = "Film")

# %%
bond.set_index("Film", inplace = True)

# %%
bond.reset_index(inplace = True)

# %%
bond.drop(["GoldenEye", "Dr. No"])

# %%
bond.drop(["Actor", "Director"], axis = 1)

# %%
#uses index value to find the remaining values
bond.loc["Goldfinger"]
#the first parameter passed is related to select the row

# %%
bond.loc["Casino Royale", ["Actor", "Box Office"]]
#the first parameter Casion Royale passed indicates Row, and the second list passsed indicates the columns

# %%
bond.iloc[10, 2:5]
#selects the values based on their index no.
